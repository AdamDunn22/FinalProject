# %%
import json
import pandas as pd
import numpy as np

# %%
pip install datapackage
# Out:
# ...
#      ---------------------------------------- 85.8/85.8 kB 2.4 MB/s eta 0:00:00
# ...
#   Preparing metadata (setup.py): started
#   Preparing metadata (setup.py): finished with status 'done'
# ...
#      ---------------------------------------- 72.1/72.1 kB 4.1 MB/s eta 0:00:00
# ...
#      ---------------------------------------- 68.9/68.9 kB 3.9 MB/s eta 0:00:00
# ...
#      ---------------------------------------- 41.7/41.7 kB ? eta 0:00:00
# ...
#   Preparing metadata (setup.py): started
#   Preparing metadata (setup.py): finished with status 'done'
# ...
#      ---------------------------------------- 48.7/48.7 kB 2.4 MB/s eta 0:00:00
# ...
#   Created wheel for unicodecsv: filename=unicodecsv-0.14.1-py3-none-any.whl size=10746 sha256=dc930d67165d299be898e6506a4d2b2ca09648c7d79ffc67e65a9bc16d039696
#   Stored in directory: c:\users\jeremy\appdata\local\pip\cache\wheels\1a\f4\8a\a5024fb77b32ed369e5c409081e5f00fbe3b92fdad653f6e69
# ...

# %%
## Getting JSON data (https://datahub.io/machine-learning/diabetes#pandas)

import datapackage
import pandas as pd

data_url = 'https://datahub.io/machine-learning/diabetes/datapackage.json'

# to load Data Package into storage
package = datapackage.Package(data_url)

# to load only tabular data
resources = package.resources
for resource in resources:
    if resource.tabular:
        data = pd.read_csv(resource.descriptor['path'])
        print (data)
# Out:
#      preg  plas  pres  skin  insu  mass   pedi  age            class
# 0       6   148    72    35     0  33.6  0.627   50  tested_positive
# 1       1    85    66    29     0  26.6  0.351   31  tested_negative
# 2       8   183    64     0     0  23.3  0.672   32  tested_positive
# 3       1    89    66    23    94  28.1  0.167   21  tested_negative
# 4       0   137    40    35   168  43.1  2.288   33  tested_positive
# ..    ...   ...   ...   ...   ...   ...    ...  ...              ...
# 763    10   101    76    48   180  32.9  0.171   63  tested_negative
# 764     2   122    70    27     0  36.8  0.340   27  tested_negative
# 765     5   121    72    23   112  26.2  0.245   30  tested_negative
# 766     1   126    60     0     0  30.1  0.349   47  tested_positive
# 767     1    93    70    31     0  30.4  0.315   23  tested_negative
#
# [768 rows x 9 columns]
#      preg  plas  pres  skin  insu  mass   pedi  age            class
# ...

# %%
df = pd.DataFrame(data)
df.head()
# Out:
#    preg  plas  pres  skin  insu  mass   pedi  age            class
# 0     6   148    72    35     0  33.6  0.627   50  tested_positive
# 1     1    85    66    29     0  26.6  0.351   31  tested_negative
# 2     8   183    64     0     0  23.3  0.672   32  tested_positive
# 3     1    89    66    23    94  28.1  0.167   21  tested_negative
# 4     0   137    40    35   168  43.1  2.288   33  tested_positive

# %%
## Cleaning Column Names and 
df = df.rename({
    'class': 'Diabetes', 
'skin': 'Skin Thickness',
'preg': 'Number of Pregnancies',
'plas': 'Blood Plasma',
'insu': 'Insulin Levels',
'mass': 'Mass (kg)',
'pres': 'Blood Pressure',
'age': 'Age'
}, axis = 1)

# %%
df.head()
# Out:
#    Number of Pregnancies  Blood Plasma  Blood Pressure  Skin Thickness  \
# 0                      6           148              72              35
# 1                      1            85              66              29
# 2                      8           183              64               0
# 3                      1            89              66              23
# 4                      0           137              40              35
#
#    Insulin Levels  Mass (kg)   pedi  Age         Diabetes
# 0               0       33.6  0.627   50  tested_positive
# 1               0       26.6  0.351   31  tested_negative
# 2               0       23.3  0.672   32  tested_positive
# 3              94       28.1  0.167   21  tested_negative
# 4             168       43.1  2.288   33  tested_positive

# %%
## changing string in 'Diabetes' to number to match other dataframes
df = df.replace({
    'tested_positive': 1,
    'tested_negative': 0
})

# %%
df.head()
# Out:
#    Number of Pregnancies  Blood Plasma  Blood Pressure  Skin Thickness  \
# 0                      6           148              72              35
# 1                      1            85              66              29
# 2                      8           183              64               0
# 3                      1            89              66              23
# 4                      0           137              40              35
#
#    Insulin Levels  Mass (kg)   pedi  Age  Diabetes
# 0               0       33.6  0.627   50         1
# 1               0       26.6  0.351   31         0
# 2               0       23.3  0.672   32         1
# 3              94       28.1  0.167   21         0
# 4             168       43.1  2.288   33         1

# %%
#save df as csv
df.to_csv('Resources/clean_data_json.csv', sep=',', index=False, header='True')
